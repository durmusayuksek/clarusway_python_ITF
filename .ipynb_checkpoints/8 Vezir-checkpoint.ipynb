# %% [markdown]
# ```
# Sekiz veziri satranç tahtasına birbirini yemeden nasıl dizersiniz?
# ```

# %%
import random
harfler = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
rakamlar = ['1', '2', '3', '4', '5', '6', '7', '8']
surec = [1, 2, 3, 4, 5, 6, 7, 8, 7, 6, 5, 4, 3, 2, 1]

def saga(text):
    iki, b, c, d = [], 0, 0, 7
    while True:
        bir, a = [], 0
        for y in rakamlar[d:]:
            bir.append(harfler[c] + y)
            a += 1
            c += 1
            if a == surec[b]:
                b += 1
                d -= 1
                c = 0
                break
        iki.append(bir)
        if b == 8:break

    while True:
        for i in harfler[1:]:
            e, g, bir = 0, 0, []
            f = harfler.index(i)
            while e < surec[b]:
                bir.append(harfler[f] + rakamlar[g])
                f += 1
                g += 1
                e += 1
            iki.append(bir)
            b += 1
        if b == len(surec):break

    for i in iki:
        if text in i:return i

def sola(text):
    uc, b, c, d = [], 0, 0, 7
    while True:
        dort, a = [], 0
        for y in rakamlar[d:]:
            dort.append(harfler[::-1][c] + y)
            a += 1
            c += 1
            if a == surec[b]:
                b += 1
                d -= 1
                c = 0
                break
        uc.append(dort)
        if b == 8:break

    while True:
        for i in harfler[::-1][1:]:
            e, g, dort = 0, 0, []
            f = harfler.index(i)
            while e < surec[b]:
                dort.append(harfler[f] + rakamlar[g])
                f -= 1
                g += 1
                e += 1
            uc.append(dort)
            b += 1
        if b == len(surec):break
    
    for i in uc:
        if text in i:return i

def yenenler(cift):
    x = int(cift[1])
    liste_2 = []
    liste = [cift[0] + i for i in rakamlar] + [i + cift[1] for i in harfler if i != cift[0]]
    for i in saga(cift):
        if i not in liste:
            liste.append(i)
    for i in sola(cift):
        if i not in liste:
            liste.append(i)
    return liste

def vezir(n):
    sayi, count, res, result = 0, 0, [], []
    while sayi < 9:
        c1 = random.choice(harfler)
        c2 = random.choice(rakamlar)
        cift = c1 + c2
        count += 1

        if count == 20000:
            res, sayi = [], 0

        if sayi == 0:
            res.append(cift)
            uzak_dur = yenenler(cift)
            sayi = 1
        else:
            if cift not in res and cift not in uzak_dur:
                res.append(cift)
                uzak_dur = uzak_dur + yenenler(cift)
                count = 0
            if len(res) == 8:
                result.append(res)
                res = []
                uzak_dur = []
                count = 0
                sayi = 0
        if len(result) == n:break
    return result

vezir(92) # maksimum 92 farkli cozumu mevcut
# Out:
# [['g5', 'b8', 'd4', 'f7', 'c2', 'e1', 'a6', 'h3'],
#  ['b6', 'g3', 'a2', 'f8', 'd7', 'h5', 'c1', 'e4'],
#  ['e8', 'g4', 'a3', 'f2', 'h6', 'b1', 'd5', 'c7'],
#  ['f4', 'c3', 'h5', 'a7', 'g2', 'e6', 'd8', 'b1'],
#  ['h2', 'c5', 'd3', 'g8', 'e1', 'b7', 'a4', 'f6'],
#  ['e1', 'h7', 'd6', 'a4', 'c8', 'b2', 'g5', 'f3'],
#  ['a5', 'g6', 'h2', 'd1', 'b7', 'c4', 'e3', 'f8'],
#  ['b4', 'c2', 'a6', 'e5', 'g1', 'd8', 'f7', 'h3'],
#  ['e7', 'h3', 'a4', 'c1', 'b8', 'f2', 'g6', 'd5'],
#  ['f2', 'b1', 'd5', 'c7', 'a3', 'g4', 'h6', 'e8'],
#  ['b7', 'e5', 'c2', 'g4', 'a3', 'f1', 'h6', 'd8'],
#  ['e1', 'f4', 'b3', 'h8', 'd7', 'g2', 'c5', 'a6'],
#  ['g1', 'a6', 'e5', 'b4', 'c2', 'h3', 'f7', 'd8'],
#  ['h3', 'b2', 'c7', 'e1', 'd5', 'a4', 'g6', 'f8'],
#  ['b3', 'd7', 'c1', 'a5', 'e2', 'h4', 'g6', 'f8'],
#  ['f5', 'd1', 'h6', 'b2', 'a7', 'c4', 'e8', 'g3'],
#  ['a6', 'h5', 'f2', 'e4', 'b3', 'c1', 'd8', 'g7'],
#  ['b3', 'd6', 'a8', 'c1', 'g7', 'h4', 'f5', 'e2'],
#  ['h2', 'f6', 'd3', 'c1', 'a5', 'e8', 'g4', 'b7'],
#  ['h1', 'f8', 'c4', 'e3', 'a5', 'd7', 'g6', 'b2'],
#  ['g8', 'a5', 'c2', 'h4', 'd6', 'e3', 'b7', 'f1'],
#  ['e4', 'g3', 'h5', 'c1', 'b6', 'a2', 'd7', 'f8'],
#  ['f4', 'g8', 'a3', 'd7', 'e1', 'c2', 'h5', 'b6'],
#  ['b1', 'a5', 'g2', 'd6', 'f7', 'e3', 'c8', 'h4'],
#  ['c7', 'e4', 'h6', 'f2', 'd1', 'a3', 'g8', 'b5'],
#  ['g5', 'f7', 'e4', 'a3', 'b6', 'd1', 'c8', 'h2'],
#  ['f4', 'e1', 'a6', 'h8', 'd7', 'g2', 'c5', 'b3'],
#  ['c3', 'f5', 'd8', 'b7', 'g1', 'h6', 'e2', 'a4'],
#  ['g1', 'b4', 'a6', 'h3', 'd8', 'e5', 'c2', 'f7'],
#  ['h5', 'e6', 'g3', 'a7', 'c2', 'd8', 'f1', 'b4'],
#  ['c7', 'g8', 'h6', 'd1', 'a3', 'e4', 'b5', 'f2'],
#  ['c1', 'b7', 'h3', 'd8', 'a4', 'f2', 'g6', 'e5'],
#  ['b6', 'g5', 'a3', 'f7', 'c8', 'd1', 'h2', 'e4'],
#  ['g8', 'e5', 'b6', 'h4', 'a3', 'd7', 'f1', 'c2'],
#  ['b7', 'e1', 'a4', 'd3', 'h2', 'c5', 'f6', 'g8'],
#  ['c2', 'e3', 'g8', 'd6', 'a5', 'b7', 'h4', 'f1'],
#  ['e8', 'c4', 'g7', 'f2', 'd6', 'a5', 'h3', 'b1'],
#  ['g6', 'b3', 'a7', 'd2', 'h4', 'f1', 'e5', 'c8'],
#  ['e7', 'h5', 'f1', 'd2', 'g3', 'c8', 'b6', 'a4'],
#  ['a4', 'h6', 'b2', 'g3', 'f1', 'c8', 'd5', 'e7'],
#  ['e2', 'a5', 'f8', 'h3', 'b7', 'd4', 'c1', 'g6'],
#  ['e6', 'd8', 'b5', 'g7', 'h1', 'c2', 'a3', 'f4'],
#  ['d4', 'a2', 'f8', 'g6', 'c7', 'e1', 'h3', 'b5'],
#  ['c5', 'h7', 'b2', 'g3', 'f1', 'a4', 'e6', 'd8'],
#  ['c7', 'e3', 'g6', 'b5', 'h4', 'd1', 'f8', 'a2'],
#  ['h2', 'b7', 'f8', 'e3', 'c4', 'a5', 'd1', 'g6'],
#  ['a5', 'b7', 'd6', 'c2', 'g8', 'f1', 'h4', 'e3'],
#  ['g5', 'b4', 'h3', 'c7', 'a6', 'd1', 'e8', 'f2'],
#  ['a5', 'g6', 'c4', 'b2', 'h1', 'd7', 'f8', 'e3'],
#  ['h8', 'a6', 'b4', 'g2', 'd1', 'c7', 'f5', 'e3'],
#  ['e2', 'f5', 'g7', 'b3', 'h4', 'c1', 'a8', 'd6'],
#  ['c3', 'a4', 'e2', 'f5', 'd8', 'h6', 'b7', 'g1'],
#  ['d5', 'f2', 'g7', 'h3', 'b4', 'a6', 'e8', 'c1'],
#  ['b3', 'd6', 'g4', 'f2', 'a5', 'e8', 'c1', 'h7'],
#  ['g4', 'b7', 'e8', 'f6', 'd3', 'c1', 'a5', 'h2'],
#  ['h5', 'a6', 'c7', 'g2', 'b3', 'd4', 'e1', 'f8'],
#  ['d1', 'e8', 'f5', 'c4', 'b2', 'h6', 'a7', 'g3'],
#  ['c4', 'h6', 'b2', 'a8', 'e7', 'g3', 'f5', 'd1'],
#  ['f5', 'g1', 'd2', 'b3', 'c7', 'e8', 'h4', 'a6'],
#  ['b6', 'f8', 'g3', 'e2', 'd5', 'a4', 'c1', 'h7'],
#  ['a4', 'c8', 'g5', 'e1', 'h2', 'd3', 'f7', 'b6'],
#  ['b5', 'e6', 'c3', 'f8', 'h4', 'a7', 'g2', 'd1'],
#  ['b2', 'h6', 'e7', 'a8', 'd1', 'f5', 'c4', 'g3'],
#  ['g6', 'b7', 'e3', 'c4', 'f8', 'h2', 'a5', 'd1'],
#  ['c4', 'h3', 'd6', 'a5', 'e8', 'g7', 'b1', 'f2'],
#  ['c4', 'b8', 'e1', 'h5', 'g2', 'd7', 'f6', 'a3'],
#  ['c2', 'e8', 'g7', 'a3', 'f1', 'd5', 'h4', 'b6'],
#  ['b3', 'g2', 'c7', 'e1', 'f8', 'h5', 'd4', 'a6'],
#  ['b5', 'c7', 'a2', 'h4', 'e3', 'g6', 'f8', 'd1'],
#  ['h6', 'f7', 'a4', 'g3', 'c5', 'e2', 'd8', 'b1'],
#  ['f1', 'd2', 'g3', 'b6', 'e7', 'c8', 'a4', 'h5'],
#  ['f6', 'g4', 'a5', 'h2', 'd3', 'b7', 'e8', 'c1'],
#  ['f1', 'a2', 'g7', 'b4', 'd8', 'e3', 'h5', 'c6'],
#  ['d6', 'e3', 'f1', 'c2', 'a5', 'g8', 'b7', 'h4'],
#  ['f1', 'g8', 'd6', 'b7', 'c2', 'a5', 'h4', 'e3'],
#  ['e5', 'a6', 'f2', 'h7', 'c1', 'b3', 'd8', 'g4'],
#  ['b2', 'g8', 'd3', 'c6', 'e1', 'h5', 'f4', 'a7'],
#  ['b1', 'g4', 'd5', 'e8', 'a3', 'h6', 'f2', 'c7'],
#  ['f7', 'e1', 'h3', 'a6', 'g5', 'c2', 'b8', 'd4'],
#  ['b3', 'c8', 'h4', 'd2', 'g6', 'f1', 'a7', 'e5'],
#  ['h3', 'a5', 'g6', 'e2', 'f8', 'd4', 'b7', 'c1'],
#  ['h5', 'f8', 'g1', 'd3', 'e6', 'a4', 'c7', 'b2'],
#  ['h5', 'b2', 'f4', 'g8', 'a7', 'd3', 'e1', 'c6'],
#  ['e3', 'h8', 'a6', 'd1', 'c7', 'b4', 'g2', 'f5'],
#  ['b3', 'd4', 'a6', 'c7', 'f8', 'g2', 'e1', 'h5'],
#  ['b5', 'f7', 'h6', 'e1', 'c8', 'g2', 'd4', 'a3'],
#  ['f2', 'e8', 'c7', 'd1', 'a6', 'g5', 'b4', 'h3'],
#  ['c8', 'a5', 'e2', 'h6', 'f7', 'g3', 'b1', 'd4'],
#  ['g8', 'f4', 'e1', 'c2', 'a3', 'b6', 'h5', 'd7'],
#  ['h6', 'd3', 'f7', 'g4', 'c5', 'a8', 'e1', 'b2'],
#  ['e3', 'f5', 'd1', 'g2', 'b4', 'a6', 'c7', 'h8'],
#  ['c5', 'a1', 'b7', 'f4', 'e2', 'h3', 'd8', 'g6']]
