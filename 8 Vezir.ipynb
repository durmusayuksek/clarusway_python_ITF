# %% [markdown]
# ```
# Sekiz veziri satranç tahtasına birbirini yemeden nasıl dizersiniz?
# ```

# %%
import random
harfler = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
rakamlar = ['1', '2', '3', '4', '5', '6', '7', '8']
surec = [1, 2, 3, 4, 5, 6, 7, 8, 7, 6, 5, 4, 3, 2, 1]

def saga(text):
    iki, b, c, d = [], 0, 0, 7
    while True:
        bir, a = [], 0
        for y in rakamlar[d:]:
            bir.append(harfler[c] + y)
            a += 1
            c += 1
            if a == surec[b]:
                b += 1
                d -= 1
                c = 0
                break
        iki.append(bir)
        if b == 8:break

    while True:
        for i in harfler[1:]:
            e, g, bir = 0, 0, []
            f = harfler.index(i)
            while e < surec[b]:
                bir.append(harfler[f] + rakamlar[g])
                f += 1
                g += 1
                e += 1
            iki.append(bir)
            b += 1
        if b == len(surec):break

    for i in iki:
        if text in i:return i

def sola(text):
    uc, b, c, d = [], 0, 0, 7
    while True:
        dort, a = [], 0
        for y in rakamlar[d:]:
            dort.append(harfler[::-1][c] + y)
            a += 1
            c += 1
            if a == surec[b]:
                b += 1
                d -= 1
                c = 0
                break
        uc.append(dort)
        if b == 8:break

    while True:
        for i in harfler[::-1][1:]:
            e, g, dort = 0, 0, []
            f = harfler.index(i)
            while e < surec[b]:
                dort.append(harfler[f] + rakamlar[g])
                f -= 1
                g += 1
                e += 1
            uc.append(dort)
            b += 1
        if b == len(surec):break
    
    for i in uc:
        if text in i:return i

def yenenler(cift):
    x = int(cift[1])
    liste_2 = []
    liste = [cift[0] + i for i in rakamlar] + [i + cift[1] for i in harfler if i != cift[0]]
    for i in saga(cift):
        if i not in liste:
            liste.append(i)
    for i in sola(cift):
        if i not in liste:
            liste.append(i)
    return liste

def vezir(n):
    sayi, count, res, result = 0, 0, [], []
    while sayi < 9:
        c1 = random.choice(harfler)
        c2 = random.choice(rakamlar)
        cift = c1 + c2
        count += 1

        if count == 20000:
            res, sayi, count = [], 0, 0

        if sayi == 0:
            res.append(cift)
            uzak_dur = yenenler(cift)
            sayi = 1
        else:
            if cift not in res and cift not in uzak_dur:
                res.append(cift)
                uzak_dur = uzak_dur + yenenler(cift)
                count = 0
            if len(res) == 8:
                result.append(res)
                res = []
                uzak_dur = []
                count = 0
                sayi = 0
        if len(result) == n:break
    return result

vezir(92) # maksimum 92 farkli cozumu mevcut
# Out:
# [['d7', 'b6', 'a3', 'c2', 'e5', 'h4', 'g8', 'f1'],
#  ['h1', 'g5', 'd3', 'e6', 'f8', 'c7', 'a4', 'b2'],
#  ['b6', 'd1', 'f7', 'e5', 'a3', 'c8', 'h4', 'g2'],
#  ['f2', 'g5', 'd1', 'c7', 'e8', 'b4', 'h3', 'a6'],
#  ['a8', 'd3', 'g4', 'f7', 'c5', 'b2', 'e1', 'h6'],
#  ['d1', 'e8', 'b6', 'h2', 'g7', 'c4', 'a3', 'f5'],
#  ['d2', 'g7', 'a3', 'f5', 'h1', 'b6', 'e8', 'c4'],
#  ['e4', 'd1', 'b5', 'c7', 'f2', 'h6', 'g8', 'a3'],
#  ['d8', 'f4', 'a3', 'b5', 'c2', 'h1', 'g7', 'e6'],
#  ['g3', 'd4', 'c2', 'h6', 'f1', 'b7', 'a5', 'e8'],
#  ['e1', 'b8', 'c5', 'f7', 'h6', 'g2', 'a4', 'd3'],
#  ['g4', 'c2', 'd8', 'b7', 'e5', 'f1', 'a3', 'h6'],
#  ['b5', 'e3', 'h4', 'g2', 'c8', 'a1', 'd6', 'f7'],
#  ['c2', 'a3', 'g4', 'b7', 'e5', 'h6', 'd8', 'f1'],
#  ['f1', 'h4', 'b7', 'c2', 'a5', 'g8', 'e3', 'd6'],
#  ['d4', 'h5', 'a6', 'b3', 'f8', 'e1', 'g2', 'c7'],
#  ['f5', 'd6', 'a2', 'e8', 'c3', 'h4', 'b7', 'g1'],
#  ['g2', 'a1', 'e7', 'd3', 'b6', 'c8', 'h5', 'f4'],
#  ['e1', 'h5', 'd3', 'g7', 'c8', 'a2', 'b6', 'f4'],
#  ['b4', 'f5', 'e3', 'd1', 'g2', 'c7', 'a6', 'h8'],
#  ['a5', 'e8', 'g4', 'h2', 'c1', 'd3', 'f6', 'b7'],
#  ['a4', 'd2', 'e6', 'c5', 'b7', 'g3', 'f1', 'h8'],
#  ['f8', 'a4', 'e6', 'd3', 'b2', 'c7', 'h5', 'g1'],
#  ['d1', 'c7', 'h8', 'a6', 'f5', 'g2', 'b4', 'e3'],
#  ['e6', 'a8', 'd3', 'g7', 'h5', 'f2', 'b4', 'c1'],
#  ['h4', 'a5', 'g6', 'e2', 'b3', 'd7', 'f8', 'c1'],
#  ['d8', 'a4', 'f3', 'g7', 'h2', 'b1', 'e6', 'c5'],
#  ['a1', 'd6', 'f7', 'h4', 'c8', 'g2', 'b5', 'e3'],
#  ['f4', 'b2', 'd3', 'g8', 'e1', 'c6', 'h5', 'a7'],
#  ['g3', 'e4', 'b6', 'd7', 'a2', 'h5', 'c1', 'f8'],
#  ['b2', 'd5', 'c8', 'h6', 'a4', 'f1', 'e7', 'g3'],
#  ['g4', 'f1', 'e3', 'b7', 'a5', 'd6', 'h8', 'c2'],
#  ['d7', 'e4', 'a2', 'f8', 'g3', 'h5', 'c1', 'b6'],
#  ['g3', 'f1', 'c5', 'd8', 'a4', 'h7', 'e6', 'b2'],
#  ['f7', 'e1', 'g5', 'h2', 'a4', 'd3', 'c8', 'b6'],
#  ['c8', 'e4', 'd1', 'g5', 'a3', 'b6', 'h2', 'f7'],
#  ['f1', 'g3', 'e7', 'c8', 'h5', 'a4', 'd2', 'b6'],
#  ['f8', 'e2', 'g6', 'h3', 'a5', 'c1', 'b7', 'd4'],
#  ['g2', 'f7', 'e3', 'd6', 'c8', 'a5', 'h4', 'b1'],
#  ['d6', 'h4', 'a2', 'g1', 'f5', 'b7', 'c3', 'e8'],
#  ['a5', 'd7', 'e3', 'g6', 'b2', 'f8', 'h1', 'c4'],
#  ['d4', 'a6', 'c7', 'b3', 'f8', 'h5', 'e1', 'g2'],
#  ['c4', 'a3', 'h1', 'f5', 'g7', 'b6', 'e8', 'd2'],
#  ['e3', 'd1', 'b7', 'a5', 'h2', 'g6', 'f8', 'c4'],
#  ['c4', 'h6', 'a8', 'f5', 'b2', 'g3', 'd1', 'e7'],
#  ['d5', 'f2', 'a6', 'b4', 'g7', 'e8', 'c1', 'h3'],
#  ['g1', 'd8', 'h3', 'b4', 'c2', 'a6', 'f7', 'e5'],
#  ['h6', 'a3', 'e4', 'g8', 'd1', 'f2', 'b5', 'c7'],
#  ['f1', 'h6', 'b7', 'e5', 'g4', 'c2', 'a3', 'd8'],
#  ['c5', 'e1', 'g4', 'h6', 'f7', 'a8', 'b2', 'd3'],
#  ['c8', 'e7', 'g6', 'a5', 'b3', 'h2', 'f1', 'd4'],
#  ['a4', 'e6', 'g3', 'c5', 'h8', 'f1', 'b7', 'd2'],
#  ['c1', 'e4', 'f8', 'd7', 'b6', 'h5', 'g3', 'a2'],
#  ['e4', 'f8', 'b6', 'g3', 'a2', 'h5', 'd7', 'c1'],
#  ['d1', 'h6', 'g8', 'e4', 'b5', 'c7', 'a3', 'f2'],
#  ['a6', 'e3', 'h4', 'b2', 'f5', 'c7', 'd1', 'g8'],
#  ['a4', 'h6', 'c5', 'e1', 'b8', 'd3', 'f7', 'g2'],
#  ['d6', 'g4', 'f2', 'e8', 'a5', 'h7', 'b3', 'c1'],
#  ['h8', 'f1', 'a4', 'c5', 'g3', 'b7', 'e6', 'd2'],
#  ['h6', 'd1', 'c4', 'a7', 'g3', 'e8', 'f5', 'b2'],
#  ['f7', 'e1', 'a8', 'd3', 'h6', 'g4', 'c5', 'b2'],
#  ['a1', 'd3', 'b6', 'g2', 'c8', 'e7', 'h5', 'f4'],
#  ['g3', 'a2', 'e4', 'f8', 'd7', 'c1', 'b6', 'h5'],
#  ['d1', 'h3', 'a5', 'g6', 'b8', 'e7', 'f2', 'c4'],
#  ['c8', 'a1', 'd3', 'f4', 'b6', 'g2', 'e7', 'h5'],
#  ['g7', 'd2', 'c8', 'a3', 'e4', 'h5', 'b6', 'f1'],
#  ['d7', 'c2', 'b6', 'h5', 'a3', 'e1', 'f4', 'g8'],
#  ['f2', 'a6', 'e8', 'b4', 'c1', 'h3', 'g7', 'd5'],
#  ['d3', 'g7', 'a4', 'h5', 'c1', 'f2', 'b8', 'e6'],
#  ['f4', 'g2', 'a6', 'h8', 'c5', 'b3', 'd7', 'e1'],
#  ['c7', 'b5', 'a2', 'h3', 'g6', 'f8', 'e1', 'd4'],
#  ['c1', 'a6', 'h4', 'f8', 'g2', 'e5', 'b3', 'd7'],
#  ['h2', 'g8', 'c5', 'e1', 'd3', 'a4', 'f6', 'b7'],
#  ['d1', 'e3', 'b5', 'f8', 'h4', 'g6', 'a2', 'c7'],
#  ['d1', 'a3', 'h2', 'f7', 'e4', 'b6', 'g5', 'c8'],
#  ['d6', 'h7', 'c4', 'f3', 'b2', 'e8', 'g1', 'a5'],
#  ['e8', 'c2', 'b4', 'f1', 'h6', 'g3', 'a7', 'd5'],
#  ['a5', 'e2', 'g6', 'h4', 'b3', 'c1', 'f8', 'd7'],
#  ['d3', 'b2', 'a4', 'h5', 'g1', 'f8', 'c7', 'e6'],
#  ['f7', 'a4', 'c5', 'b8', 'g2', 'd3', 'e1', 'h6'],
#  ['b2', 'a8', 'h6', 'g3', 'd1', 'e7', 'c4', 'f5'],
#  ['d6', 'g1', 'a2', 'b7', 'e8', 'h4', 'c3', 'f5'],
#  ['c8', 'b5', 'e3', 'h4', 'g2', 'd6', 'f7', 'a1'],
#  ['c6', 'f4', 'g8', 'e1', 'a7', 'd3', 'h5', 'b2'],
#  ['e6', 'a3', 'd8', 'g1', 'f4', 'h5', 'b7', 'c2'],
#  ['e4', 'b6', 'f8', 'a2', 'g3', 'h5', 'c1', 'd7'],
#  ['b7', 'g6', 'e1', 'c5', 'h3', 'f4', 'a2', 'd8'],
#  ['f5', 'a3', 'b6', 'g7', 'd2', 'e8', 'h1', 'c4'],
#  ['a4', 'd8', 'h2', 'f3', 'b1', 'e6', 'c5', 'g7'],
#  ['f4', 'e7', 'd1', 'c6', 'g8', 'b2', 'h3', 'a5'],
#  ['a3', 'g2', 'e1', 'c8', 'd4', 'f7', 'h6', 'b5'],
#  ['a5', 'e8', 'c2', 'f1', 'g3', 'd4', 'h6', 'b7']]
