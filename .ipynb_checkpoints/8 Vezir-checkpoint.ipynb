# %% [markdown]
# ```
# Sekiz veziri satranç tahtasına birbirini yemeden nasıl dizersiniz?
# ```

# %%
import random
harfler = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
rakamlar = ['1', '2', '3', '4', '5', '6', '7', '8']
surec = [1, 2, 3, 4, 5, 6, 7, 8, 7, 6, 5, 4, 3, 2, 1]

def saga(text):
    iki, b, c, d = [], 0, 0, 7
    while True:
        bir, a = [], 0
        for y in rakamlar[d:]:
            bir.append(harfler[c] + y)
            a += 1
            c += 1
            if a == surec[b]:
                b += 1
                d -= 1
                c = 0
                break
        iki.append(bir)
        if b == 8:break

    while True:
        for i in harfler[1:]:
            e, g, bir = 0, 0, []
            f = harfler.index(i)
            while e < surec[b]:
                bir.append(harfler[f] + rakamlar[g])
                f += 1
                g += 1
                e += 1
            iki.append(bir)
            b += 1
        if b == len(surec):break

    for i in iki:
        if text in i:return i

def sola(text):
    uc, b, c, d = [], 0, 0, 7
    while True:
        dort, a = [], 0
        for y in rakamlar[d:]:
            dort.append(harfler[::-1][c] + y)
            a += 1
            c += 1
            if a == surec[b]:
                b += 1
                d -= 1
                c = 0
                break
        uc.append(dort)
        if b == 8:break

    while True:
        for i in harfler[::-1][1:]:
            e, g, dort = 0, 0, []
            f = harfler.index(i)
            while e < surec[b]:
                dort.append(harfler[f] + rakamlar[g])
                f -= 1
                g += 1
                e += 1
            uc.append(dort)
            b += 1
        if b == len(surec):break
    
    for i in uc:
        if text in i:return i

def yenenler(cift):
    liste = [cift[0] + i for i in rakamlar] + [i + cift[1] for i in harfler if i != cift[0]]
    for i in saga(cift):
        if i not in liste:
            liste.append(i)
    for i in sola(cift):
        if i not in liste:
            liste.append(i)
    return liste

def vezir(n):
    sayi, count, res, result = 0, 0, [], []
    while sayi < 9:
        c1 = random.choice(harfler)
        c2 = random.choice(rakamlar)
        cift = c1 + c2
        count += 1

        if count == 20000:
            res, sayi, count = [], 0, 0

        if sayi == 0:
            res.append(cift)
            uzak_dur = yenenler(cift)
            sayi = 1
        else:
            if cift not in res and cift not in uzak_dur:
                res.append(cift)
                uzak_dur = uzak_dur + yenenler(cift)
                count = 0
            if len(res) == 8:
                if res not in result:
                    result.append(res)
                    res = []
                    uzak_dur = []
                    count = 0
                    sayi = 0
        if len(result) == n:break
    return result

vezir(92) # maksimum 92 farkli cozumu mevcut
# Out:
# [['c7', 'a2', 'f8', 'd1', 'e3', 'h4', 'g6', 'b5'],
#  ['e6', 'h7', 'b2', 'g3', 'a4', 'c5', 'f1', 'd8'],
#  ['e5', 'f7', 'c8', 'h4', 'g2', 'a3', 'b6', 'd1'],
#  ['c2', 'a3', 'h5', 'g1', 'd8', 'b7', 'e6', 'f4'],
#  ['e3', 'd1', 'b7', 'f8', 'h2', 'a5', 'g6', 'c4'],
#  ['e1', 'd3', 'c5', 'g8', 'f6', 'a4', 'h2', 'b7'],
#  ['b7', 'e2', 'f8', 'c1', 'h3', 'd4', 'a5', 'g6'],
#  ['b7', 'f5', 'a4', 'c3', 'd8', 'e2', 'g1', 'h6'],
#  ['h7', 'f4', 'a6', 'e1', 'b3', 'c5', 'g2', 'd8'],
#  ['b7', 'e5', 'c2', 'f1', 'g4', 'h6', 'd8', 'a3'],
#  ['e8', 'd5', 'f1', 'b6', 'h4', 'a3', 'c2', 'g7'],
#  ['b2', 'f4', 'e1', 'a7', 'h5', 'd3', 'c6', 'g8'],
#  ['e1', 'f4', 'd3', 'a2', 'b6', 'c8', 'h5', 'g7'],
#  ['f6', 'c1', 'd3', 'e8', 'h2', 'g4', 'b7', 'a5'],
#  ['e3', 'f1', 'b4', 'h5', 'c6', 'd8', 'a2', 'g7'],
#  ['e1', 'd3', 'c8', 'b6', 'g7', 'a2', 'f4', 'h5'],
#  ['a5', 'f4', 'd1', 'g8', 'b2', 'c6', 'h3', 'e7'],
#  ['a5', 'b8', 'f6', 'c4', 'g2', 'd1', 'h7', 'e3'],
#  ['d7', 'g6', 'h1', 'f8', 'b2', 'c4', 'e3', 'a5'],
#  ['b8', 'a4', 'h3', 'f2', 'c1', 'd5', 'e7', 'g6'],
#  ['c1', 'f2', 'g7', 'd5', 'e8', 'h3', 'b4', 'a6'],
#  ['e8', 'c4', 'b7', 'g5', 'f2', 'h3', 'a1', 'd6'],
#  ['h3', 'g6', 'a5', 'b7', 'f8', 'c1', 'd4', 'e2'],
#  ['d3', 'f2', 'b8', 'h5', 'e6', 'g7', 'c1', 'a4'],
#  ['d2', 'f1', 'a7', 'c8', 'b3', 'e5', 'h4', 'g6'],
#  ['f3', 'a4', 'g7', 'd8', 'e6', 'b1', 'c5', 'h2'],
#  ['c8', 'h6', 'd4', 'b5', 'a3', 'e1', 'f7', 'g2'],
#  ['c3', 'h5', 'a7', 'f4', 'g2', 'd8', 'b1', 'e6'],
#  ['e4', 'h6', 'd1', 'b5', 'g8', 'a3', 'f2', 'c7'],
#  ['c2', 'd8', 'g1', 'e5', 'a6', 'h3', 'f7', 'b4'],
#  ['d1', 'a2', 'c7', 'g6', 'e3', 'f8', 'h4', 'b5'],
#  ['e6', 'g3', 'd2', 'f1', 'b7', 'h8', 'a4', 'c5'],
#  ['d3', 'e6', 'g7', 'h5', 'c1', 'b8', 'a4', 'f2'],
#  ['g1', 'b7', 'f4', 'h5', 'c2', 'd8', 'a3', 'e6'],
#  ['e8', 'd6', 'c1', 'g4', 'a5', 'f2', 'h7', 'b3'],
#  ['f6', 'h7', 'c4', 'd1', 'a5', 'e3', 'b8', 'g2'],
#  ['e4', 'f7', 'b6', 'a3', 'h2', 'c8', 'd1', 'g5'],
#  ['d8', 'a3', 'e6', 'g1', 'b7', 'f4', 'h5', 'c2'],
#  ['h8', 'a6', 'c5', 'e1', 'b3', 'f4', 'g2', 'd7'],
#  ['f1', 'a5', 'd6', 'b7', 'c2', 'h4', 'g8', 'e3'],
#  ['g1', 'f8', 'b2', 'e6', 'c7', 'h5', 'a4', 'd3'],
#  ['f3', 'g1', 'h7', 'a5', 'd6', 'c4', 'e8', 'b2'],
#  ['h2', 'a3', 'f7', 'e4', 'd1', 'g5', 'c8', 'b6'],
#  ['h6', 'g3', 'b4', 'e8', 'c2', 'a7', 'd5', 'f1'],
#  ['a4', 'h6', 'f1', 'c8', 'b2', 'g3', 'e7', 'd5'],
#  ['e8', 'd2', 'f3', 'c5', 'b1', 'h4', 'a6', 'g7'],
#  ['g6', 'b7', 'h3', 'e5', 'f2', 'a4', 'c1', 'd8'],
#  ['c2', 'd5', 'e8', 'h4', 'b6', 'f1', 'a3', 'g7'],
#  ['h5', 'c1', 'b8', 'g7', 'f2', 'e6', 'a4', 'd3'],
#  ['a5', 'e3', 'b7', 'f8', 'd1', 'c4', 'h2', 'g6'],
#  ['a3', 'c7', 'g4', 'd5', 'e8', 'b1', 'h6', 'f2'],
#  ['h5', 'g7', 'a3', 'f1', 'c8', 'b6', 'e4', 'd2'],
#  ['d3', 'f4', 'e1', 'b6', 'g7', 'h5', 'a2', 'c8'],
#  ['c6', 'h4', 'e3', 'a2', 'g7', 'd1', 'f5', 'b8'],
#  ['a2', 'h5', 'b6', 'e4', 'd7', 'c1', 'f8', 'g3'],
#  ['e6', 'd8', 'g3', 'a4', 'b2', 'h7', 'f1', 'c5'],
#  ['h4', 'a7', 'b3', 'e8', 'g2', 'f5', 'c1', 'd6'],
#  ['e2', 'd5', 'a4', 'c1', 'h7', 'f8', 'b6', 'g3'],
#  ['h6', 'c4', 'e8', 'b2', 'f5', 'a7', 'g3', 'd1'],
#  ['c8', 'f1', 'e4', 'd2', 'a3', 'h5', 'b6', 'g7'],
#  ['f1', 'd2', 'b6', 'e4', 'g7', 'h5', 'a3', 'c8'],
#  ['f2', 'e8', 'a5', 'g7', 'b1', 'd6', 'h3', 'c4'],
#  ['d7', 'c4', 'f6', 'h5', 'b8', 'e1', 'g2', 'a3'],
#  ['f8', 'b2', 'h5', 'a4', 'd3', 'g1', 'c7', 'e6'],
#  ['e5', 'f7', 'c2', 'd8', 'h3', 'b4', 'g1', 'a6'],
#  ['d4', 'b7', 'a5', 'g3', 'e8', 'h6', 'f1', 'c2'],
#  ['e3', 'h4', 'd6', 'b7', 'a5', 'f1', 'g8', 'c2'],
#  ['d8', 'c1', 'a6', 'f2', 'e4', 'g7', 'h5', 'b3'],
#  ['a4', 'b2', 'e6', 'd8', 'f1', 'h7', 'c5', 'g3'],
#  ['h7', 'a5', 'e3', 'f6', 'd1', 'g2', 'c4', 'b8'],
#  ['h6', 'f5', 'd1', 'b2', 'a8', 'c4', 'g3', 'e7'],
#  ['f2', 'a5', 'g6', 'b8', 'd1', 'c4', 'e7', 'h3'],
#  ['d5', 'a3', 'f2', 'h6', 'b1', 'e8', 'g4', 'c7'],
#  ['b5', 'f2', 'c7', 'g8', 'e4', 'h6', 'd1', 'a3'],
#  ['a3', 'd2', 'g7', 'e8', 'c4', 'b6', 'f5', 'h1'],
#  ['d8', 'f1', 'g7', 'e3', 'a2', 'b4', 'h5', 'c6'],
#  ['g7', 'a4', 'c5', 'e6', 'f3', 'b1', 'h2', 'd8'],
#  ['d6', 'e3', 'a5', 'b7', 'g8', 'h4', 'c2', 'f1'],
#  ['a3', 'd5', 'b6', 'e8', 'c2', 'h4', 'f1', 'g7'],
#  ['c1', 'g6', 'e2', 'a5', 'b3', 'f8', 'd7', 'h4'],
#  ['f8', 'c1', 'd5', 'a4', 'h7', 'b6', 'e2', 'g3'],
#  ['a4', 'c7', 'd3', 'b2', 'g5', 'f8', 'h1', 'e6'],
#  ['d3', 'a2', 'e1', 'g7', 'c8', 'b6', 'h5', 'f4'],
#  ['d4', 'e2', 'c8', 'f7', 'a5', 'h6', 'b1', 'g3'],
#  ['a5', 'c1', 'g4', 'h7', 'e8', 'd6', 'f2', 'b3'],
#  ['f6', 'e8', 'd3', 'h2', 'a5', 'b7', 'g4', 'c1'],
#  ['b7', 'e5', 'f1', 'g4', 'a3', 'd8', 'c2', 'h6'],
#  ['h2', 'f3', 'b1', 'd8', 'a4', 'e6', 'g7', 'c5'],
#  ['e2', 'b3', 'd7', 'h4', 'c1', 'a5', 'g6', 'f8'],
#  ['a4', 'e6', 'c7', 'd3', 'f8', 'h1', 'b2', 'g5'],
#  ['a3', 'b6', 'e8', 'c4', 'f5', 'g7', 'h2', 'd1'],
#  ['c1', 'b3', 'a5', 'e8', 'h7', 'f2', 'g4', 'd6']]
